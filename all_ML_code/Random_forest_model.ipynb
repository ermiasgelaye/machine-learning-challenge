# %%
# # Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
# # install joblib. This will be used to save your model. 
# # Restart your kernel after installing 
# !pip install joblib
# !pip install yellowbrick

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
# Read in csv
df = pd.read_csv("data/exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select features (columns)

# %%
# Set target, features and feature_names.
target = df["koi_disposition"]
data = df.drop("koi_disposition", axis=1)
feature_names = data.columns
data.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %% [markdown]
# # Create a Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6122              0              0              0              0    6.768901
# 6370              0              1              0              1    0.733726
# 2879              1              0              0              0    7.652707
# 107               0              0              0              0    7.953547
# 29                0              0              0              0    4.959319
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6122     7.380000e-05    -7.380000e-05   133.077240          0.008440
# 6370     6.060000e-06    -6.060000e-06   132.020050          0.007950
# 2879     6.540000e-05    -6.540000e-05   134.460380          0.006190
# 107      1.910000e-05    -1.910000e-05   174.662240          0.001820
# 29       5.150000e-07    -5.150000e-07   172.258529          0.000083
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 6122         -0.008440  ...            -171      4.327           0.153
# 6370         -0.007950  ...            -175      4.578           0.033
# 2879         -0.006190  ...            -189      4.481           0.050
# 107          -0.001820  ...             -85      4.536           0.056
# 29           -0.000083  ...             -77      4.359           0.110
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 6122          -0.187     1.125          0.310         -0.207  294.40472
# 6370          -0.187     0.797          0.211         -0.056  284.50391
# 2879          -0.200     0.963          0.290         -0.097  295.50211
# 107           -0.016     0.779          0.023         -0.049  291.15878
# 29            -0.110     1.082          0.173         -0.130  292.16705
#
#             dec  koi_kepmag
# 6122  39.351681      14.725
# 6370  42.463860      15.770
# 2879  38.983540      13.099
# 107   40.750271      15.660
# 29    48.727589      15.263
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing

# %% [markdown]
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
from sklearn.preprocessing import MinMaxScaler
X_minmax = MinMaxScaler().fit(X_train)

X_train_minmax = X_minmax.transform(X_train)
X_test_minmax = X_minmax.transform(X_test)

# %% [markdown]
# # Train the Model (Random Forest)

# %%
from sklearn.ensemble import RandomForestClassifier
randomforest = RandomForestClassifier()
randomforest.fit(X_train_minmax, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
print(f"Training Data Score: {randomforest.score(X_train_minmax, y_train)}")
print(f"Testing Data Score: {randomforest.score(X_test_minmax, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.898741418764302

# %%
sorted(zip(randomforest.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.10954365082772755, 'koi_fpflag_co'),
#  (0.10582272040582452, 'koi_fpflag_nt'),
#  (0.06879897557694072, 'koi_fpflag_ss'),
#  (0.061260140516208456, 'koi_model_snr'),
#  (0.040580925524467584, 'koi_prad'),
#  (0.03934640177251236, 'koi_fpflag_ec'),
#  (0.0338370909473518, 'koi_duration_err1'),
#  (0.03333114191824223, 'koi_prad_err1'),
#  (0.03156462448727556, 'koi_duration_err2'),
#  (0.03138043020186252, 'koi_steff_err1'),
#  (0.030131481572970683, 'koi_prad_err2'),
#  (0.027650355248159668, 'koi_steff_err2'),
#  (0.02295893665613482, 'koi_depth'),
#  (0.02253042775581122, 'koi_period'),
#  (0.021156141220545002, 'koi_duration'),
#  (0.02060628541656678, 'koi_impact'),
#  (0.020577196945667602, 'koi_time0bk_err2'),
#  (0.020529378284217387, 'koi_time0bk_err1'),
#  (0.018555222661616744, 'koi_period_err1'),
#  (0.01718949862809284, 'koi_insol'),
#  (0.016564943898714598, 'koi_depth_err2'),
#  (0.015465590468223636, 'koi_insol_err1'),
#  (0.015335705572516138, 'koi_teq'),
#  (0.014146607249095113, 'koi_period_err2'),
#  (0.014119949764386637, 'koi_time0bk'),
#  (0.011976511196162712, 'koi_depth_err1'),
#  (0.011475368622669953, 'koi_kepmag'),
#  (0.011353572658739796, 'ra'),
#  (0.011158448174332942, 'koi_impact_err1'),
#  (0.011076054587478847, 'koi_impact_err2'),
#  (0.01094311281497631, 'koi_slogg_err2'),
#  (0.010891251168158709, 'koi_srad_err1'),
#  (0.010683587065894945, 'dec'),
#  (0.010292106209083482, 'koi_steff'),
#  (0.009550160488610984, 'koi_slogg'),
#  (0.009217475528771002, 'koi_insol_err2'),
#  (0.008965565014020254, 'koi_srad'),
#  (0.008331524124113717, 'koi_slogg_err1'),
#  (0.007910874811050782, 'koi_srad_err2'),
#  (0.0031905640148034795, 'koi_tce_plnt_num')]

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# Use GridSearchCV to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'n_estimators': [250, 300, 350],
              'max_depth': [125, 150, 175]}
grid = GridSearchCV(randomforest, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_minmax, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] max_depth=125, n_estimators=250 .................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ..... max_depth=125, n_estimators=250, score=0.897, total=   7.4s
# [CV] max_depth=125, n_estimators=250 .................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    7.4s remaining:    0.0s
# [CV] ..... max_depth=125, n_estimators=250, score=0.907, total=   7.9s
# [CV] max_depth=125, n_estimators=250 .................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   15.3s remaining:    0.0s
# [CV] ..... max_depth=125, n_estimators=250, score=0.890, total=   7.5s
# [CV] max_depth=125, n_estimators=250 .................................
# [CV] ..... max_depth=125, n_estimators=250, score=0.883, total=   7.1s
# [CV] max_depth=125, n_estimators=250 .................................
# [CV] ..... max_depth=125, n_estimators=250, score=0.879, total=   8.2s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.897, total=   9.0s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.908, total=   9.3s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.881, total=   8.4s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.877, total=   7.5s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.884, total=   8.7s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.904, total=   6.5s
# [CV] max_depth=125, n_estimators=350 .................................

# %%
print(grid.best_params_)
print(grid.best_score_)

# %%
# Training score:
grid.score(X_train_minmax, y_train)

# %%
# Testing score:
grid.score(X_test_minmax, y_test)

# %%
# Make prediction and save to variable for report.
predictions = grid.predict(X_test_minmax)

# %%
# Print Classification Report.
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))

# %%
# %matplotlib notebook
from yellowbrick.classifier import ClassificationReport
viz = ClassificationReport(RandomForestClassifier(),cmap="PuBu")
viz.fit(X_train_minmax, y_train)
viz.score(X_test_minmax, y_test)
viz.finalize()
viz.show(outpath="image/randomforest_classifier.png")

# %%
from yellowbrick.model_selection import FeatureImportances
from yellowbrick.style import set_palette
from yellowbrick.features import RadViz
viz = FeatureImportances(randomforest,size=(700, 500),color='b', align='center')
viz.fit(X_train_minmax, y_train)
viz.show(outpath="image/rf_featureimportance.png")

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'model_sav/ermias_gaga_randomForest.sav'
joblib.dump(randomforest, filename)
